# %%
import pandas as pd

# %%
df = pd.read_excel('final_places.xlsx')
df
# Out:
#       Destination                            Place  Rating  \
# 0             Goa                  Calangute Beach     4.4
# 1             Goa            Basilica of Bom Jesus     4.3
# 2             Goa              Water Sports in Goa     4.4
# 3             Goa                      Fort Aguada     4.4
# 4             Goa                       Baga Beach     4.5
# ...           ...                              ...     ...
# 2625  Honnemaradu                            Sagar     3.2
# 2626  Honnemaradu                        Jog Falls     3.1
# 2627  Honnemaradu                     Burude Falls     3.4
# 2628  Honnemaradu  Singadooru Chaundeshwari Temple     3.1
# 2629  Honnemaradu          Trekking in Honnemaradu     3.1
#
#                                             Description  religious  \
# 0     Calangute is a largest beach in north Goa stre...          1
# 1     This historic church is located in Goa and is ...         -1
# ...

# %%
df = df.drop(['Place', 'Rating', 'Description'], axis = 1)
df = df.groupby(['Destination']).mean()

# %%
df
# Out:
#                          religious  conventional  commotion       fun
# Destination
# Agartala                  0.333333     -1.000000   1.000000  1.000000
# Agra                      0.882353     -1.000000   0.411765  0.176471
# Ahmedabad                 0.476190     -1.000000   0.285714  0.095238
# Ajanta and Ellora Caves   0.333333     -1.000000   0.833333  0.833333
# Ajmer                     0.391304     -1.000000   0.913043  0.739130
# ...                            ...           ...        ...       ...
# Varanasi                 -0.157895     -0.894737  -0.210526  0.736842
# Varkala                   0.304348     -0.913043   0.652174  0.739130
# Visakhapatnam             0.680000     -0.680000   0.840000  0.840000
# Vrindavan                -1.000000     -1.000000   1.000000  1.000000
# Wayanad                   0.470588     -0.705882   0.823529  0.882353
#
# [95 rows x 4 columns]

# %%
df.to_csv('final_pred.csv')

# %%
df
# Out:
#                          religious  conventional  commotion       fun
# Destination
# Agartala                  0.333333     -1.000000   1.000000  1.000000
# Agra                      0.882353     -1.000000   0.411765  0.176471
# Ahmedabad                 0.476190     -1.000000   0.285714  0.095238
# Ajanta and Ellora Caves   0.333333     -1.000000   0.833333  0.833333
# Ajmer                     0.391304     -1.000000   0.913043  0.739130
# ...                            ...           ...        ...       ...
# Varanasi                 -0.157895     -0.894737  -0.210526  0.736842
# Varkala                   0.304348     -0.913043   0.652174  0.739130
# Visakhapatnam             0.680000     -0.680000   0.840000  0.840000
# Vrindavan                -1.000000     -1.000000   1.000000  1.000000
# Wayanad                   0.470588     -0.705882   0.823529  0.882353
#
# [95 rows x 4 columns]
